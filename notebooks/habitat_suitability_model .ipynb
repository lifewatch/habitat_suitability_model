# %%
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# 01_setup
##################################################################################
##################################################################################

# Author: Nowé Jo-Hannes
# Email: johannes.nowe@vliz.be
# Date: 2025-03-19
# Script Name: ~/habitat_suitability_model/code/0_1setup.R
# Script Description: A script to make the general folder structure and load the necessary packages.
# Also load custom functions and the given user inputs.
# SETUP ------------------------------------


##################################################################################
##################################################################################
install.packages("renv", repos = "https://rstudio.r-universe.dev")
install.packages("IMIS", repos = "https://rstudio.r-universe.dev")

# FUNCTIONS ---------------------------------------------------------------
lapply(list.files("functions", full.names = TRUE),source)
# INPUT -------------------------------------------------------------------

# WORKFLOW ----------------------------------------------------------------
# Define different folders
downloaddir <- "data/raw_data"
datadir     <- "data/derived_data"
mapsdir     <- "results/geospatial_layers"
modeldir   <- "results/models"
figdir    <- "results/figures_tables"
envdir <-"data/raw_data/environmental_layers"
occdir <-"data/raw_data/occurrences"
spatdir <- "data/raw_data/spatial_layers"
scriptsdir <- "code/"
folderstruc <- c(downloaddir,
                 datadir,
                 mapsdir,
                 modeldir,
                 figdir,
                 envdir,
                 occdir,
                 spatdir,
                 scriptsdir)

#Check for their existence, create if missing
for(i in 1:length(folderstruc)){
  if(!dir.exists(folderstruc[i])){
    # If not, create the folder
    dir.create(folderstruc[i],recursive = TRUE)
    cat("Folder created:", folderstruc[i], "\n")
  } else {
    cat("Folder already exists:", folderstruc[i], "\n")
  }
}

#Download the necessary R packages
if(!require('renv'))install.packages('renv')
#Possibly re-start R for renv/activate.R to work.
package_list <- c("arrow",
                  "bundle",
                  "CAST",
                  "CoordinateCleaner",
                  "dismo",
                  "doFuture",
                  "doParallel",
                  "downloader",
                  "foreach",
                  "future",
                  "GeoThinneR",
                  "ks",
                  "mgcv",
                  "modEvA",
                  "ows4R",
                  "randomForest",
                  "ranger",
                  "raster",
                  "sdm",
                  "sf",
                  "sp",
                  "spatialEco",
                  "spatstat",
                  "stacks",
                  "stats",
                  "terra",
                  "tidymodels",
                  "tidysdm",
                  "tidyverse",
                  "utils",
                  "worrms",
                  "xgboost")
#Load all the packages with library()
lapply(package_list, require, character.only = TRUE)
library(imis)

#Define user input choices
study_area <- load_ospar(c("II","III"), filepath = file.path(spatdir,"ospar_regions_2017_01_002.shp"))
bbox <- sf::st_bbox(study_area)
date_start <- as.POSIXct("1999-01-01")
date_end <- as.POSIXct("2019-12-31")
temporal_extent <- lubridate::interval(date_start,date_end)
possible_aphiaids <- c(137117, 137084, 137094, 137111, 137101, 137087)
aphiaid <- possible_aphiaids[1]

#Choosing the bounding box to assess the monthly trend
min_lon <- 1.8
max_lon <- 2.5
min_lat <- 51
max_lat <- 52

# OUTPUT ------------------------------------------------------------------
# Out:
# list()
# Folder already exists: data/raw_data
# Folder already exists: data/derived_data
# Folder already exists: results/geospatial_layers
# Folder already exists: results/models
# Folder already exists: results/figures_tables
# Folder already exists: data/raw_data/environmental_layers
# Folder already exists: data/raw_data/occurrences
# Folder already exists: data/raw_data/spatial_layers
# Folder already exists: code/
# Loading required package: renv
#
#
# Attaching package: ‘renv’
#
#
# The following objects are masked from ‘package:stats’:
#
#     embed, update
#
#
# The following objects are masked from ‘package:utils’:
#
#     history, upgrade
#
#
# The following objects are masked from ‘package:base’:
#
#     autoload, load, remove, use
#
#
# Loading required package: arrow
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘arrow’”
# Loading required package: bundle
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘bundle’”
# Loading required package: CAST
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘CAST’”
# Loading required package: CoordinateCleaner
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘CoordinateCleaner’”
# Loading required package: dismo
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘dismo’”
# Loading required package: doFuture
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘doFuture’”
# Loading required package: doParallel
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘doParallel’”
# Loading required package: downloader
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘downloader’”
# Loading required package: foreach
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘foreach’”
# Loading required package: future
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘future’”
# Loading required package: GeoThinneR
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘GeoThinneR’”
# Loading required package: ks
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘ks’”
# Loading required package: modEvA
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘modEvA’”
# Loading required package: ows4R
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘ows4R’”
# Loading required package: randomForest
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘randomForest’”
# Loading required package: ranger
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘ranger’”
# Loading required package: raster
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘raster’”
# Loading required package: sdm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘sdm’”
# Loading required package: sf
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘sf’”
# Loading required package: sp
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘sp’”
# Loading required package: spatialEco
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘spatialEco’”
# Loading required package: spatstat
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘spatstat’”
# Loading required package: stacks
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘stacks’”
# Loading required package: terra
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘terra’”
# Loading required package: tidymodels
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘tidymodels’”
# Loading required package: tidysdm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘tidysdm’”
# Loading required package: tidyverse
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘tidyverse’”
# Loading required package: worrms
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘worrms’”
# Loading required package: xgboost
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘xgboost’”
# [[1]]
# [1] FALSE
#
# [[2]]
# [1] FALSE
#
# [[3]]
# [1] FALSE
#
# [[4]]
# [1] FALSE
#
# [[5]]
# [1] FALSE
#
# [[6]]
# [1] FALSE
#
# [[7]]
# [1] FALSE
#
# [[8]]
# [1] FALSE
#
# [[9]]
# [1] FALSE
#
# [[10]]
# [1] FALSE
#
# [[11]]
# [1] FALSE
#
# [[12]]
# [1] FALSE
#
# [[13]]
# [1] TRUE
#
# [[14]]
# [1] FALSE
#
# [[15]]
# [1] FALSE
#
# [[16]]
# [1] FALSE
#
# [[17]]
# [1] FALSE
#
# [[18]]
# [1] FALSE
#
# [[19]]
# [1] FALSE
#
# [[20]]
# [1] FALSE
#
# [[21]]
# [1] FALSE
#
# [[22]]
# [1] FALSE
#
# [[23]]
# [1] FALSE
#
# [[24]]
# [1] FALSE
#
# [[25]]
# [1] TRUE
#
# [[26]]
# [1] FALSE
#
# [[27]]
# [1] FALSE
#
# [[28]]
# [1] FALSE
#
# [[29]]
# [1] FALSE
#
# [[30]]
# [1] TRUE
#
# [[31]]
# [1] FALSE
#
# [[32]]
# [1] FALSE
# Error in library(imis): there is no package called ‘imis’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))
